# %% [markdown]
# # Emotion Detection AI
#
# This notebook trains a simple emotion classifier and tests sample predictions.

# %%
from emotion_model import train_model, predict_emotion

result = train_model()
print(f'Accuracy: {result.accuracy:.2f}')

# %%
samples = [
    'I am excited for this trip',
    'I feel awful and lonely',
    'I am terrified of losing my job',
]
predict_emotion(result.model, samples)
